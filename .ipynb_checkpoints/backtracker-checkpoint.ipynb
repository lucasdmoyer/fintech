# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import backtrader as bt
import pandas as pd
from yahoofinancials import YahooFinancials
from pandas_datareader import data
from yahoofinancials import YahooFinancials as YF
import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# %%
if __name__ == '__main__':
    cerebro = bt.Cerebro()

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# %%
def getStocks():
    table = pd.read_html(
        'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    df = table[0]
    df.to_csv('S&P500-Info.csv')
    df.to_csv("S&P500-Symbols.csv", columns=['Symbol'])
    tickers = df['Symbol'][:50]
    result = []
    tickers = {}
    for tick in tickers:
        data = bt.feeds.YahooFinanceData(
            dataname=tick,
            # Do not pass values before this date
            fromdate=datetime.datetime(2019, 1, 1),
            # Do not pass values after this date
            todate=datetime.datetime(2020, 12, 31),
            reverse=False)
        tickers[tick]=result.length
        result.append(data)
    return (tickers,result)

stocks = getStocks()

# %%
stocks
# Out:
# ({}, [])

# %% [markdown]
# # If stock falls 3 straight, buy

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        if self.dataclose[0] < self.dataclose[-1]:
            # current close less than previous close

            if self.dataclose[-1] < self.dataclose[-2]:
                # previous close less than the previous close

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.buy()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceData(
        dataname="AAPL",
        # Do not pass values before this date
        fromdate=datetime.datetime(2000, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2000, 12, 31),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2000-01-03, Close, 0.86
# 2000-01-04, Close, 0.79
# 2000-01-05, Close, 0.80
# 2000-01-06, Close, 0.73
# 2000-01-07, Close, 0.77
# 2000-01-10, Close, 0.75
# 2000-01-11, Close, 0.71
# 2000-01-11, BUY CREATE, 0.71
# 2000-01-12, Close, 0.67
# 2000-01-12, BUY CREATE, 0.67
# 2000-01-13, Close, 0.75
# 2000-01-14, Close, 0.77
# 2000-01-18, Close, 0.80
# 2000-01-19, Close, 0.82
# 2000-01-20, Close, 0.87
# 2000-01-21, Close, 0.86
# 2000-01-24, Close, 0.82
# 2000-01-24, BUY CREATE, 0.82
# 2000-01-25, Close, 0.86
# 2000-01-26, Close, 0.85
# 2000-01-27, Close, 0.85
# 2000-01-28, Close, 0.78
# 2000-01-31, Close, 0.80
# 2000-02-01, Close, 0.77
# 2000-02-02, Close, 0.76
# 2000-02-02, BUY CREATE, 0.76
# 2000-02-03, Close, 0.80
# 2000-02-04, Close, 0.83
# 2000-02-07, Close, 0.88
# 2000-02-08, Close, 0.88
# 2000-02-09, Close, 0.87
# 2000-02-10, Close, 0.87
# 2000-02-11, Close, 0.84
# 2000-02-14, Close, 0.89
# 2000-02-15, Close, 0.92
# 2000-02-16, Close, 0.88
# 2000-02-17, Close, 0.88
# 2000-02-18, Close, 0.86
# 2000-02-22, Close, 0.88
# 2000-02-23, Close, 0.90
# 2000-02-24, Close, 0.89
# 2000-02-25, Close, 0.85
# 2000-02-25, BUY CREATE, 0.85
# 2000-02-28, Close, 0.87
# 2000-02-29, Close, 0.88
# 2000-03-01, Close, 1.00
# 2000-03-02, Close, 0.94
# 2000-03-03, Close, 0.99
# 2000-03-06, Close, 0.97
# 2000-03-07, Close, 0.95
# 2000-03-07, BUY CREATE, 0.95
# 2000-03-08, Close, 0.94
# 2000-03-08, BUY CREATE, 0.94
# 2000-03-09, Close, 0.94
# 2000-03-10, Close, 0.97
# 2000-03-13, Close, 0.93
# 2000-03-14, Close, 0.88
# 2000-03-14, BUY CREATE, 0.88
# 2000-03-15, Close, 0.90
# 2000-03-16, Close, 0.94
# 2000-03-17, Close, 0.96
# 2000-03-20, Close, 0.95
# 2000-03-21, Close, 1.04
# 2000-03-22, Close, 1.11
# 2000-03-23, Close, 1.09
# 2000-03-24, Close, 1.07
# 2000-03-24, BUY CREATE, 1.07
# 2000-03-27, Close, 1.07
# 2000-03-28, Close, 1.07
# 2000-03-29, Close, 1.05
# 2000-03-30, Close, 0.97
# 2000-03-30, BUY CREATE, 0.97
# 2000-03-31, Close, 1.05
# 2000-04-03, Close, 1.03
# 2000-04-04, Close, 0.98
# 2000-04-04, BUY CREATE, 0.98
# 2000-04-05, Close, 1.00
# 2000-04-06, Close, 0.96
# 2000-04-07, Close, 1.01
# 2000-04-10, Close, 0.96
# 2000-04-11, Close, 0.92
# 2000-04-11, BUY CREATE, 0.92
# 2000-04-12, Close, 0.84
# 2000-04-12, BUY CREATE, 0.84
# 2000-04-13, Close, 0.88
# 2000-04-14, Close, 0.86
# 2000-04-17, Close, 0.95
# 2000-04-18, Close, 0.98
# 2000-04-19, Close, 0.93
# 2000-04-20, Close, 0.92
# 2000-04-20, BUY CREATE, 0.92
# 2000-04-24, Close, 0.93
# 2000-04-25, Close, 0.99
# 2000-04-26, Close, 0.93
# 2000-04-27, Close, 0.98
# 2000-04-28, Close, 0.96
# 2000-05-01, Close, 0.96
# 2000-05-02, Close, 0.91
# 2000-05-03, Close, 0.89
# 2000-05-03, BUY CREATE, 0.89
# 2000-05-04, Close, 0.85
# 2000-05-04, BUY CREATE, 0.85
# 2000-05-05, Close, 0.87
# 2000-05-08, Close, 0.85
# 2000-05-09, Close, 0.81
# 2000-05-09, BUY CREATE, 0.81
# 2000-05-10, Close, 0.76
# 2000-05-10, BUY CREATE, 0.76
# 2000-05-11, Close, 0.79
# 2000-05-12, Close, 0.83
# 2000-05-15, Close, 0.78
# 2000-05-16, Close, 0.81
# 2000-05-17, Close, 0.78
# 2000-05-18, Close, 0.78
# 2000-05-19, Close, 0.72
# 2000-05-22, Close, 0.69
# 2000-05-22, BUY CREATE, 0.69
# 2000-05-23, Close, 0.66
# 2000-05-23, BUY CREATE, 0.66
# 2000-05-24, Close, 0.68
# 2000-05-25, Close, 0.67
# 2000-05-26, Close, 0.67
# 2000-05-30, Close, 0.67
# 2000-05-31, Close, 0.65
# 2000-06-01, Close, 0.69
# 2000-06-02, Close, 0.71
# 2000-06-05, Close, 0.70
# 2000-06-06, Close, 0.72
# 2000-06-07, Close, 0.74
# 2000-06-08, Close, 0.73
# 2000-06-09, Close, 0.74
# 2000-06-12, Close, 0.70
# 2000-06-13, Close, 0.73
# 2000-06-14, Close, 0.70
# 2000-06-15, Close, 0.71
# 2000-06-16, Close, 0.70
# 2000-06-19, Close, 0.74
# 2000-06-20, Close, 0.78
# 2000-06-21, Close, 0.86
# 2000-06-22, Close, 0.83
# 2000-06-23, Close, 0.80
# 2000-06-23, BUY CREATE, 0.80
# 2000-06-26, Close, 0.83
# 2000-06-27, Close, 0.80
# 2000-06-28, Close, 0.84
# 2000-06-29, Close, 0.79
# 2000-06-30, Close, 0.81
# 2000-07-03, Close, 0.82
# 2000-07-05, Close, 0.80
# 2000-07-06, Close, 0.80
# 2000-07-07, Close, 0.84
# 2000-07-10, Close, 0.88
# 2000-07-11, Close, 0.88
# 2000-07-12, Close, 0.91
# 2000-07-13, Close, 0.87
# 2000-07-14, Close, 0.89
# 2000-07-17, Close, 0.90
# 2000-07-18, Close, 0.88
# 2000-07-19, Close, 0.81
# 2000-07-19, BUY CREATE, 0.81
# 2000-07-20, Close, 0.85
# 2000-07-21, Close, 0.83
# 2000-07-24, Close, 0.75
# 2000-07-24, BUY CREATE, 0.75
# 2000-07-25, Close, 0.77
# 2000-07-26, Close, 0.77
# 2000-07-27, Close, 0.80
# 2000-07-28, Close, 0.74
# 2000-07-31, Close, 0.78
# 2000-08-01, Close, 0.76
# 2000-08-02, Close, 0.73
# 2000-08-02, BUY CREATE, 0.73
# 2000-08-03, Close, 0.74
# 2000-08-04, Close, 0.73
# 2000-08-07, Close, 0.74
# 2000-08-08, Close, 0.72
# 2000-08-09, Close, 0.73
# 2000-08-10, Close, 0.73
# 2000-08-11, Close, 0.73
# 2000-08-14, Close, 0.72
# 2000-08-15, Close, 0.72
# 2000-08-16, Close, 0.75
# 2000-08-17, Close, 0.79
# 2000-08-18, Close, 0.77
# 2000-08-21, Close, 0.78
# 2000-08-22, Close, 0.80
# 2000-08-23, Close, 0.84
# 2000-08-24, Close, 0.86
# 2000-08-25, Close, 0.88
# 2000-08-28, Close, 0.89
# 2000-08-29, Close, 0.91
# 2000-08-30, Close, 0.92
# 2000-08-31, Close, 0.94
# 2000-09-01, Close, 0.98
# 2000-09-05, Close, 0.96
# 2000-09-06, Close, 0.90
# 2000-09-06, BUY CREATE, 0.90
# 2000-09-07, Close, 0.96
# 2000-09-08, Close, 0.91
# 2000-09-11, Close, 0.90
# 2000-09-11, BUY CREATE, 0.90
# 2000-09-12, Close, 0.89
# 2000-09-12, BUY CREATE, 0.89
# 2000-09-13, Close, 0.89
# 2000-09-14, Close, 0.88
# 2000-09-15, Close, 0.85
# 2000-09-15, BUY CREATE, 0.85
# 2000-09-18, Close, 0.93
# 2000-09-19, Close, 0.92
# 2000-09-20, Close, 0.94
# 2000-09-21, Close, 0.87
# 2000-09-22, Close, 0.80
# 2000-09-22, BUY CREATE, 0.80
# 2000-09-25, Close, 0.82
# 2000-09-26, Close, 0.79
# 2000-09-27, Close, 0.75
# 2000-09-27, BUY CREATE, 0.75
# 2000-09-28, Close, 0.82
# 2000-09-29, Close, 0.40
# 2000-10-02, Close, 0.37
# 2000-10-02, BUY CREATE, 0.37
# 2000-10-03, Close, 0.34
# 2000-10-03, BUY CREATE, 0.34
# 2000-10-04, Close, 0.36
# 2000-10-05, Close, 0.34
# 2000-10-06, Close, 0.34
# 2000-10-09, Close, 0.34
# 2000-10-10, Close, 0.32
# 2000-10-11, Close, 0.30
# 2000-10-11, BUY CREATE, 0.30
# 2000-10-12, Close, 0.31
# 2000-10-13, Close, 0.34
# 2000-10-16, Close, 0.33
# 2000-10-17, Close, 0.31
# 2000-10-17, BUY CREATE, 0.31
# 2000-10-18, Close, 0.31
# 2000-10-19, Close, 0.29
# 2000-10-20, Close, 0.30
# 2000-10-23, Close, 0.31
# 2000-10-24, Close, 0.29
# 2000-10-25, Close, 0.28
# 2000-10-25, BUY CREATE, 0.28
# 2000-10-26, Close, 0.28
# 2000-10-27, Close, 0.29
# 2000-10-30, Close, 0.30
# 2000-10-31, Close, 0.30
# 2000-11-01, Close, 0.32
# 2000-11-02, Close, 0.34
# 2000-11-03, Close, 0.34
# 2000-11-06, Close, 0.33
# 2000-11-07, Close, 0.33
# 2000-11-08, Close, 0.31
# 2000-11-09, Close, 0.31
# 2000-11-10, Close, 0.29
# 2000-11-13, Close, 0.30
# 2000-11-14, Close, 0.31
# 2000-11-15, Close, 0.31
# 2000-11-16, Close, 0.29
# 2000-11-17, Close, 0.28
# 2000-11-17, BUY CREATE, 0.28
# 2000-11-20, Close, 0.29
# 2000-11-21, Close, 0.29
# 2000-11-22, Close, 0.28
# 2000-11-24, Close, 0.30
# 2000-11-27, Close, 0.29
# 2000-11-28, Close, 0.28
# 2000-11-28, BUY CREATE, 0.28
# 2000-11-29, Close, 0.27
# 2000-11-29, BUY CREATE, 0.27
# 2000-11-30, Close, 0.25
# 2000-11-30, BUY CREATE, 0.25
# 2000-12-01, Close, 0.26
# 2000-12-04, Close, 0.26
# 2000-12-05, Close, 0.26
# 2000-12-06, Close, 0.22
# 2000-12-07, Close, 0.22
# 2000-12-08, Close, 0.23
# 2000-12-11, Close, 0.23
# 2000-12-12, Close, 0.24
# 2000-12-13, Close, 0.23
# 2000-12-14, Close, 0.22
# 2000-12-14, BUY CREATE, 0.22
# 2000-12-15, Close, 0.22
# 2000-12-18, Close, 0.22
# 2000-12-19, Close, 0.22
# 2000-12-20, Close, 0.22
# 2000-12-21, Close, 0.22
# 2000-12-22, Close, 0.23
# 2000-12-26, Close, 0.23
# 2000-12-27, Close, 0.23
# 2000-12-28, Close, 0.23
# 2000-12-29, Close, 0.23
# Final Portfolio Value: 99981.03

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('exitbars', 5),
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + self.params.exitbars):
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceData(
        dataname="AAPL",
        # Do not pass values before this date
        fromdate=datetime.datetime(2000, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2000, 12, 31),
        reverse=False)
        
    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2000-01-03, Close, 0.86
# 2000-01-04, Close, 0.79
# 2000-01-05, Close, 0.80
# 2000-01-06, Close, 0.73
# 2000-01-07, Close, 0.77
# 2000-01-10, Close, 0.75
# 2000-01-11, Close, 0.71
# 2000-01-11, BUY CREATE, 0.71
# 2000-01-12, BUY EXECUTED, Price: 0.73, Cost: 0.73, Comm 0.00
# 2000-01-12, Close, 0.67
# 2000-01-13, Close, 0.75
# 2000-01-14, Close, 0.77
# 2000-01-18, Close, 0.80
# 2000-01-19, Close, 0.82
# 2000-01-20, Close, 0.87
# 2000-01-20, SELL CREATE, 0.87
# 2000-01-21, SELL EXECUTED, Price: 0.88, Cost: 0.73, Comm 0.00
# 2000-01-21, OPERATION PROFIT, GROSS 0.15, NET 0.15
# 2000-01-21, Close, 0.86
# 2000-01-24, Close, 0.82
# 2000-01-24, BUY CREATE, 0.82
# 2000-01-25, BUY EXECUTED, Price: 0.81, Cost: 0.81, Comm 0.00
# 2000-01-25, Close, 0.86
# 2000-01-26, Close, 0.85
# 2000-01-27, Close, 0.85
# 2000-01-28, Close, 0.78
# 2000-01-31, Close, 0.80
# 2000-02-01, Close, 0.77
# 2000-02-01, SELL CREATE, 0.77
# 2000-02-02, SELL EXECUTED, Price: 0.78, Cost: 0.81, Comm 0.00
# 2000-02-02, OPERATION PROFIT, GROSS -0.03, NET -0.03
# 2000-02-02, Close, 0.76
# 2000-02-02, BUY CREATE, 0.76
# 2000-02-03, BUY EXECUTED, Price: 0.77, Cost: 0.77, Comm 0.00
# 2000-02-03, Close, 0.80
# 2000-02-04, Close, 0.83
# 2000-02-07, Close, 0.88
# 2000-02-08, Close, 0.88
# 2000-02-09, Close, 0.87
# 2000-02-10, Close, 0.87
# 2000-02-10, SELL CREATE, 0.87
# 2000-02-11, SELL EXECUTED, Price: 0.88, Cost: 0.77, Comm 0.00
# 2000-02-11, OPERATION PROFIT, GROSS 0.11, NET 0.11
# 2000-02-11, Close, 0.84
# 2000-02-14, Close, 0.89
# 2000-02-15, Close, 0.92
# 2000-02-16, Close, 0.88
# 2000-02-17, Close, 0.88
# 2000-02-18, Close, 0.86
# 2000-02-22, Close, 0.88
# 2000-02-23, Close, 0.90
# 2000-02-24, Close, 0.89
# 2000-02-25, Close, 0.85
# 2000-02-25, BUY CREATE, 0.85
# 2000-02-28, BUY EXECUTED, Price: 0.85, Cost: 0.85, Comm 0.00
# 2000-02-28, Close, 0.87
# 2000-02-29, Close, 0.88
# 2000-03-01, Close, 1.00
# 2000-03-02, Close, 0.94
# 2000-03-03, Close, 0.99
# 2000-03-06, Close, 0.97
# 2000-03-06, SELL CREATE, 0.97
# 2000-03-07, SELL EXECUTED, Price: 0.97, Cost: 0.85, Comm 0.00
# 2000-03-07, OPERATION PROFIT, GROSS 0.12, NET 0.12
# 2000-03-07, Close, 0.95
# 2000-03-07, BUY CREATE, 0.95
# 2000-03-08, BUY EXECUTED, Price: 0.95, Cost: 0.95, Comm 0.00
# 2000-03-08, Close, 0.94
# 2000-03-09, Close, 0.94
# 2000-03-10, Close, 0.97
# 2000-03-13, Close, 0.93
# 2000-03-14, Close, 0.88
# 2000-03-15, Close, 0.90
# 2000-03-15, SELL CREATE, 0.90
# 2000-03-16, SELL EXECUTED, Price: 0.90, Cost: 0.95, Comm 0.00
# 2000-03-16, OPERATION PROFIT, GROSS -0.05, NET -0.05
# 2000-03-16, Close, 0.94
# 2000-03-17, Close, 0.96
# 2000-03-20, Close, 0.95
# 2000-03-21, Close, 1.04
# 2000-03-22, Close, 1.11
# 2000-03-23, Close, 1.09
# 2000-03-24, Close, 1.07
# 2000-03-24, BUY CREATE, 1.07
# 2000-03-27, BUY EXECUTED, Price: 1.06, Cost: 1.06, Comm 0.00
# 2000-03-27, Close, 1.07
# 2000-03-28, Close, 1.07
# 2000-03-29, Close, 1.05
# 2000-03-30, Close, 0.97
# 2000-03-31, Close, 1.05
# 2000-04-03, Close, 1.03
# 2000-04-03, SELL CREATE, 1.03
# 2000-04-04, SELL EXECUTED, Price: 1.02, Cost: 1.06, Comm 0.00
# 2000-04-04, OPERATION PROFIT, GROSS -0.04, NET -0.04
# 2000-04-04, Close, 0.98
# 2000-04-04, BUY CREATE, 0.98
# 2000-04-05, BUY EXECUTED, Price: 0.97, Cost: 0.97, Comm 0.00
# 2000-04-05, Close, 1.00
# 2000-04-06, Close, 0.96
# 2000-04-07, Close, 1.01
# 2000-04-10, Close, 0.96
# 2000-04-11, Close, 0.92
# 2000-04-12, Close, 0.84
# 2000-04-12, SELL CREATE, 0.84
# 2000-04-13, SELL EXECUTED, Price: 0.86, Cost: 0.97, Comm 0.00
# 2000-04-13, OPERATION PROFIT, GROSS -0.11, NET -0.11
# 2000-04-13, Close, 0.88
# 2000-04-14, Close, 0.86
# 2000-04-17, Close, 0.95
# 2000-04-18, Close, 0.98
# 2000-04-19, Close, 0.93
# 2000-04-20, Close, 0.92
# 2000-04-20, BUY CREATE, 0.92
# 2000-04-24, BUY EXECUTED, Price: 0.89, Cost: 0.89, Comm 0.00
# 2000-04-24, Close, 0.93
# 2000-04-25, Close, 0.99
# 2000-04-26, Close, 0.93
# 2000-04-27, Close, 0.98
# 2000-04-28, Close, 0.96
# 2000-05-01, Close, 0.96
# 2000-05-01, SELL CREATE, 0.96
# 2000-05-02, SELL EXECUTED, Price: 0.95, Cost: 0.89, Comm 0.00
# 2000-05-02, OPERATION PROFIT, GROSS 0.06, NET 0.06
# 2000-05-02, Close, 0.91
# 2000-05-03, Close, 0.89
# 2000-05-03, BUY CREATE, 0.89
# 2000-05-04, BUY EXECUTED, Price: 0.89, Cost: 0.89, Comm 0.00
# 2000-05-04, Close, 0.85
# 2000-05-05, Close, 0.87
# 2000-05-08, Close, 0.85
# 2000-05-09, Close, 0.81
# 2000-05-10, Close, 0.76
# 2000-05-11, Close, 0.79
# 2000-05-11, SELL CREATE, 0.79
# 2000-05-12, SELL EXECUTED, Price: 0.82, Cost: 0.89, Comm 0.00
# 2000-05-12, OPERATION PROFIT, GROSS -0.07, NET -0.07
# 2000-05-12, Close, 0.83
# 2000-05-15, Close, 0.78
# 2000-05-16, Close, 0.81
# 2000-05-17, Close, 0.78
# 2000-05-18, Close, 0.78
# 2000-05-19, Close, 0.72
# 2000-05-22, Close, 0.69
# 2000-05-22, BUY CREATE, 0.69
# 2000-05-23, BUY EXECUTED, Price: 0.70, Cost: 0.70, Comm 0.00
# 2000-05-23, Close, 0.66
# 2000-05-24, Close, 0.68
# 2000-05-25, Close, 0.67
# 2000-05-26, Close, 0.67
# 2000-05-30, Close, 0.67
# 2000-05-31, Close, 0.65
# 2000-05-31, SELL CREATE, 0.65
# 2000-06-01, SELL EXECUTED, Price: 0.63, Cost: 0.70, Comm 0.00
# 2000-06-01, OPERATION PROFIT, GROSS -0.07, NET -0.07
# 2000-06-01, Close, 0.69
# 2000-06-02, Close, 0.71
# 2000-06-05, Close, 0.70
# 2000-06-06, Close, 0.72
# 2000-06-07, Close, 0.74
# 2000-06-08, Close, 0.73
# 2000-06-09, Close, 0.74
# 2000-06-12, Close, 0.70
# 2000-06-13, Close, 0.73
# 2000-06-14, Close, 0.70
# 2000-06-15, Close, 0.71
# 2000-06-16, Close, 0.70
# 2000-06-19, Close, 0.74
# 2000-06-20, Close, 0.78
# 2000-06-21, Close, 0.86
# 2000-06-22, Close, 0.83
# 2000-06-23, Close, 0.80
# 2000-06-23, BUY CREATE, 0.80
# 2000-06-26, BUY EXECUTED, Price: 0.81, Cost: 0.81, Comm 0.00
# 2000-06-26, Close, 0.83
# 2000-06-27, Close, 0.80
# 2000-06-28, Close, 0.84
# 2000-06-29, Close, 0.79
# 2000-06-30, Close, 0.81
# 2000-07-03, Close, 0.82
# 2000-07-03, SELL CREATE, 0.82
# 2000-07-05, SELL EXECUTED, Price: 0.82, Cost: 0.81, Comm 0.00
# 2000-07-05, OPERATION PROFIT, GROSS 0.01, NET 0.01
# 2000-07-05, Close, 0.80
# 2000-07-06, Close, 0.80
# 2000-07-07, Close, 0.84
# 2000-07-10, Close, 0.88
# 2000-07-11, Close, 0.88
# 2000-07-12, Close, 0.91
# 2000-07-13, Close, 0.87
# 2000-07-14, Close, 0.89
# 2000-07-17, Close, 0.90
# 2000-07-18, Close, 0.88
# 2000-07-19, Close, 0.81
# 2000-07-19, BUY CREATE, 0.81
# 2000-07-20, BUY EXECUTED, Price: 0.85, Cost: 0.85, Comm 0.00
# 2000-07-20, Close, 0.85
# 2000-07-21, Close, 0.83
# 2000-07-24, Close, 0.75
# 2000-07-25, Close, 0.77
# 2000-07-26, Close, 0.77
# 2000-07-27, Close, 0.80
# 2000-07-27, SELL CREATE, 0.80
# 2000-07-28, SELL EXECUTED, Price: 0.81, Cost: 0.85, Comm 0.00
# 2000-07-28, OPERATION PROFIT, GROSS -0.04, NET -0.04
# 2000-07-28, Close, 0.74
# 2000-07-31, Close, 0.78
# 2000-08-01, Close, 0.76
# 2000-08-02, Close, 0.73
# 2000-08-02, BUY CREATE, 0.73
# 2000-08-03, BUY EXECUTED, Price: 0.70, Cost: 0.70, Comm 0.00
# 2000-08-03, Close, 0.74
# 2000-08-04, Close, 0.73
# 2000-08-07, Close, 0.74
# 2000-08-08, Close, 0.72
# 2000-08-09, Close, 0.73
# 2000-08-10, Close, 0.73
# 2000-08-10, SELL CREATE, 0.73
# 2000-08-11, SELL EXECUTED, Price: 0.72, Cost: 0.70, Comm 0.00
# 2000-08-11, OPERATION PROFIT, GROSS 0.02, NET 0.02
# 2000-08-11, Close, 0.73
# 2000-08-14, Close, 0.72
# 2000-08-15, Close, 0.72
# 2000-08-16, Close, 0.75
# 2000-08-17, Close, 0.79
# 2000-08-18, Close, 0.77
# 2000-08-21, Close, 0.78
# 2000-08-22, Close, 0.80
# 2000-08-23, Close, 0.84
# 2000-08-24, Close, 0.86
# 2000-08-25, Close, 0.88
# 2000-08-28, Close, 0.89
# 2000-08-29, Close, 0.91
# 2000-08-30, Close, 0.92
# 2000-08-31, Close, 0.94
# 2000-09-01, Close, 0.98
# 2000-09-05, Close, 0.96
# 2000-09-06, Close, 0.90
# 2000-09-06, BUY CREATE, 0.90
# 2000-09-07, BUY EXECUTED, Price: 0.91, Cost: 0.91, Comm 0.00
# 2000-09-07, Close, 0.96
# 2000-09-08, Close, 0.91
# 2000-09-11, Close, 0.90
# 2000-09-12, Close, 0.89
# 2000-09-13, Close, 0.89
# 2000-09-14, Close, 0.88
# 2000-09-14, SELL CREATE, 0.88
# 2000-09-15, SELL EXECUTED, Price: 0.89, Cost: 0.91, Comm 0.00
# 2000-09-15, OPERATION PROFIT, GROSS -0.02, NET -0.02
# 2000-09-15, Close, 0.85
# 2000-09-15, BUY CREATE, 0.85
# 2000-09-18, BUY EXECUTED, Price: 0.85, Cost: 0.85, Comm 0.00
# 2000-09-18, Close, 0.93
# 2000-09-19, Close, 0.92
# 2000-09-20, Close, 0.94
# 2000-09-21, Close, 0.87
# 2000-09-22, Close, 0.80
# 2000-09-25, Close, 0.82
# 2000-09-25, SELL CREATE, 0.82
# 2000-09-26, SELL EXECUTED, Price: 0.82, Cost: 0.85, Comm 0.00
# 2000-09-26, OPERATION PROFIT, GROSS -0.03, NET -0.03
# 2000-09-26, Close, 0.79
# 2000-09-27, Close, 0.75
# 2000-09-27, BUY CREATE, 0.75
# 2000-09-28, BUY EXECUTED, Price: 0.76, Cost: 0.76, Comm 0.00
# 2000-09-28, Close, 0.82
# 2000-09-29, Close, 0.40
# 2000-10-02, Close, 0.37
# 2000-10-03, Close, 0.34
# 2000-10-04, Close, 0.36
# 2000-10-05, Close, 0.34
# 2000-10-05, SELL CREATE, 0.34
# 2000-10-06, SELL EXECUTED, Price: 0.35, Cost: 0.76, Comm 0.00
# 2000-10-06, OPERATION PROFIT, GROSS -0.41, NET -0.41
# 2000-10-06, Close, 0.34
# 2000-10-09, Close, 0.34
# 2000-10-10, Close, 0.32
# 2000-10-11, Close, 0.30
# 2000-10-11, BUY CREATE, 0.30
# 2000-10-12, BUY EXECUTED, Price: 0.31, Cost: 0.31, Comm 0.00
# 2000-10-12, Close, 0.31
# 2000-10-13, Close, 0.34
# 2000-10-16, Close, 0.33
# 2000-10-17, Close, 0.31
# 2000-10-18, Close, 0.31
# 2000-10-19, Close, 0.29
# 2000-10-19, SELL CREATE, 0.29
# 2000-10-20, SELL EXECUTED, Price: 0.29, Cost: 0.31, Comm 0.00
# 2000-10-20, OPERATION PROFIT, GROSS -0.02, NET -0.02
# 2000-10-20, Close, 0.30
# 2000-10-23, Close, 0.31
# 2000-10-24, Close, 0.29
# 2000-10-25, Close, 0.28
# 2000-10-25, BUY CREATE, 0.28
# 2000-10-26, BUY EXECUTED, Price: 0.29, Cost: 0.29, Comm 0.00
# 2000-10-26, Close, 0.28
# 2000-10-27, Close, 0.29
# 2000-10-30, Close, 0.30
# 2000-10-31, Close, 0.30
# 2000-11-01, Close, 0.32
# 2000-11-02, Close, 0.34
# 2000-11-02, SELL CREATE, 0.34
# 2000-11-03, SELL EXECUTED, Price: 0.35, Cost: 0.29, Comm 0.00
# 2000-11-03, OPERATION PROFIT, GROSS 0.06, NET 0.06
# 2000-11-03, Close, 0.34
# 2000-11-06, Close, 0.33
# 2000-11-07, Close, 0.33
# 2000-11-08, Close, 0.31
# 2000-11-09, Close, 0.31
# 2000-11-10, Close, 0.29
# 2000-11-13, Close, 0.30
# 2000-11-14, Close, 0.31
# 2000-11-15, Close, 0.31
# 2000-11-16, Close, 0.29
# 2000-11-17, Close, 0.28
# 2000-11-17, BUY CREATE, 0.28
# 2000-11-20, BUY EXECUTED, Price: 0.29, Cost: 0.29, Comm 0.00
# 2000-11-20, Close, 0.29
# 2000-11-21, Close, 0.29
# 2000-11-22, Close, 0.28
# 2000-11-24, Close, 0.30
# 2000-11-27, Close, 0.29
# 2000-11-28, Close, 0.28
# 2000-11-28, SELL CREATE, 0.28
# 2000-11-29, SELL EXECUTED, Price: 0.28, Cost: 0.29, Comm 0.00
# 2000-11-29, OPERATION PROFIT, GROSS -0.01, NET -0.01
# 2000-11-29, Close, 0.27
# 2000-11-29, BUY CREATE, 0.27
# 2000-11-30, BUY EXECUTED, Price: 0.26, Cost: 0.26, Comm 0.00
# 2000-11-30, Close, 0.25
# 2000-12-01, Close, 0.26
# 2000-12-04, Close, 0.26
# 2000-12-05, Close, 0.26
# 2000-12-06, Close, 0.22
# 2000-12-07, Close, 0.22
# 2000-12-07, SELL CREATE, 0.22
# 2000-12-08, SELL EXECUTED, Price: 0.23, Cost: 0.26, Comm 0.00
# 2000-12-08, OPERATION PROFIT, GROSS -0.03, NET -0.03
# 2000-12-08, Close, 0.23
# 2000-12-11, Close, 0.23
# 2000-12-12, Close, 0.24
# 2000-12-13, Close, 0.23
# 2000-12-14, Close, 0.22
# 2000-12-14, BUY CREATE, 0.22
# 2000-12-15, BUY EXECUTED, Price: 0.22, Cost: 0.22, Comm 0.00
# 2000-12-15, Close, 0.22
# 2000-12-18, Close, 0.22
# 2000-12-19, Close, 0.22
# 2000-12-20, Close, 0.22
# 2000-12-21, Close, 0.22
# 2000-12-22, Close, 0.23
# 2000-12-22, SELL CREATE, 0.23
# 2000-12-26, SELL EXECUTED, Price: 0.23, Cost: 0.22, Comm 0.00
# 2000-12-26, OPERATION PROFIT, GROSS 0.01, NET 0.01
# 2000-12-26, Close, 0.23
# 2000-12-27, Close, 0.23
# 2000-12-28, Close, 0.23
# 2000-12-29, Close, 0.23
# Final Portfolio Value: 99999.58

# %%
# Indicators
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 5),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] > self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceData(
        dataname="AAPL",
        # Do not pass values before this date
        fromdate=datetime.datetime(2000, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2000, 12, 31),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 1000.00
# 2000-01-07, Close, 0.77
# 2000-01-07, BUY CREATE, 0.77
# 2000-01-10, BUY EXECUTED, Price: 0.79, Cost: 7.90, Comm 0.00
# 2000-01-10, Close, 0.75
# 2000-01-11, Close, 0.71
# 2000-01-12, Close, 0.67
# 2000-01-13, Close, 0.75
# 2000-01-13, SELL CREATE, 0.75
# 2000-01-14, SELL EXECUTED, Price: 0.77, Cost: 7.90, Comm 0.00
# 2000-01-14, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-01-14, Close, 0.77
# 2000-01-18, Close, 0.80
# 2000-01-19, Close, 0.82
# 2000-01-20, Close, 0.87
# 2000-01-21, Close, 0.86
# 2000-01-24, Close, 0.82
# 2000-01-24, BUY CREATE, 0.82
# 2000-01-25, BUY EXECUTED, Price: 0.81, Cost: 8.10, Comm 0.00
# 2000-01-25, Close, 0.86
# 2000-01-25, SELL CREATE, 0.86
# 2000-01-26, SELL EXECUTED, Price: 0.85, Cost: 8.10, Comm 0.00
# 2000-01-26, OPERATION PROFIT, GROSS 0.40, NET 0.40
# 2000-01-26, Close, 0.85
# 2000-01-26, BUY CREATE, 0.85
# 2000-01-27, BUY EXECUTED, Price: 0.84, Cost: 8.40, Comm 0.00
# 2000-01-27, Close, 0.85
# 2000-01-27, SELL CREATE, 0.85
# 2000-01-28, SELL EXECUTED, Price: 0.83, Cost: 8.40, Comm 0.00
# 2000-01-28, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2000-01-28, Close, 0.78
# 2000-01-28, BUY CREATE, 0.78
# 2000-01-31, BUY EXECUTED, Price: 0.78, Cost: 7.80, Comm 0.00
# 2000-01-31, Close, 0.80
# 2000-02-01, Close, 0.77
# 2000-02-02, Close, 0.76
# 2000-02-03, Close, 0.80
# 2000-02-03, SELL CREATE, 0.80
# 2000-02-04, SELL EXECUTED, Price: 0.80, Cost: 7.80, Comm 0.00
# 2000-02-04, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-02-04, Close, 0.83
# 2000-02-07, Close, 0.88
# 2000-02-08, Close, 0.88
# 2000-02-09, Close, 0.87
# 2000-02-10, Close, 0.87
# 2000-02-11, Close, 0.84
# 2000-02-11, BUY CREATE, 0.84
# 2000-02-14, BUY EXECUTED, Price: 0.84, Cost: 8.40, Comm 0.00
# 2000-02-14, Close, 0.89
# 2000-02-14, SELL CREATE, 0.89
# 2000-02-15, SELL EXECUTED, Price: 0.89, Cost: 8.40, Comm 0.00
# 2000-02-15, OPERATION PROFIT, GROSS 0.50, NET 0.50
# 2000-02-15, Close, 0.92
# 2000-02-16, Close, 0.88
# 2000-02-16, BUY CREATE, 0.88
# 2000-02-17, BUY EXECUTED, Price: 0.89, Cost: 8.90, Comm 0.00
# 2000-02-17, Close, 0.88
# 2000-02-18, Close, 0.86
# 2000-02-22, Close, 0.88
# 2000-02-23, Close, 0.90
# 2000-02-23, SELL CREATE, 0.90
# 2000-02-24, SELL EXECUTED, Price: 0.90, Cost: 8.90, Comm 0.00
# 2000-02-24, OPERATION PROFIT, GROSS 0.10, NET 0.10
# 2000-02-24, Close, 0.89
# 2000-02-25, Close, 0.85
# 2000-02-25, BUY CREATE, 0.85
# 2000-02-28, BUY EXECUTED, Price: 0.85, Cost: 8.50, Comm 0.00
# 2000-02-28, Close, 0.87
# 2000-02-29, Close, 0.88
# 2000-02-29, SELL CREATE, 0.88
# 2000-03-01, SELL EXECUTED, Price: 0.91, Cost: 8.50, Comm 0.00
# 2000-03-01, OPERATION PROFIT, GROSS 0.60, NET 0.60
# 2000-03-01, Close, 1.00
# 2000-03-02, Close, 0.94
# 2000-03-03, Close, 0.99
# 2000-03-06, Close, 0.97
# 2000-03-07, Close, 0.95
# 2000-03-07, BUY CREATE, 0.95
# 2000-03-08, BUY EXECUTED, Price: 0.95, Cost: 9.50, Comm 0.00
# 2000-03-08, Close, 0.94
# 2000-03-09, Close, 0.94
# 2000-03-10, Close, 0.97
# 2000-03-10, SELL CREATE, 0.97
# 2000-03-13, SELL EXECUTED, Price: 0.94, Cost: 9.50, Comm 0.00
# 2000-03-13, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2000-03-13, Close, 0.93
# 2000-03-13, BUY CREATE, 0.93
# 2000-03-14, BUY EXECUTED, Price: 0.93, Cost: 9.30, Comm 0.00
# 2000-03-14, Close, 0.88
# 2000-03-15, Close, 0.90
# 2000-03-16, Close, 0.94
# 2000-03-16, SELL CREATE, 0.94
# 2000-03-17, SELL EXECUTED, Price: 0.93, Cost: 9.30, Comm 0.00
# 2000-03-17, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2000-03-17, Close, 0.96
# 2000-03-20, Close, 0.95
# 2000-03-21, Close, 1.04
# 2000-03-22, Close, 1.11
# 2000-03-23, Close, 1.09
# 2000-03-24, Close, 1.07
# 2000-03-27, Close, 1.07
# 2000-03-27, BUY CREATE, 1.07
# 2000-03-28, BUY EXECUTED, Price: 1.06, Cost: 10.60, Comm 0.00
# 2000-03-28, Close, 1.07
# 2000-03-29, Close, 1.05
# 2000-03-30, Close, 0.97
# 2000-03-31, Close, 1.05
# 2000-03-31, SELL CREATE, 1.05
# 2000-04-03, SELL EXECUTED, Price: 1.04, Cost: 10.60, Comm 0.00
# 2000-04-03, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-04-03, Close, 1.03
# 2000-04-03, BUY CREATE, 1.03
# 2000-04-04, BUY EXECUTED, Price: 1.02, Cost: 10.20, Comm 0.00
# 2000-04-04, Close, 0.98
# 2000-04-05, Close, 1.00
# 2000-04-06, Close, 0.96
# 2000-04-07, Close, 1.01
# 2000-04-07, SELL CREATE, 1.01
# 2000-04-10, SELL EXECUTED, Price: 1.01, Cost: 10.20, Comm 0.00
# 2000-04-10, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2000-04-10, Close, 0.96
# 2000-04-10, BUY CREATE, 0.96
# 2000-04-11, BUY EXECUTED, Price: 0.95, Cost: 9.50, Comm 0.00
# 2000-04-11, Close, 0.92
# 2000-04-12, Close, 0.84
# 2000-04-13, Close, 0.88
# 2000-04-14, Close, 0.86
# 2000-04-17, Close, 0.95
# 2000-04-17, SELL CREATE, 0.95
# 2000-04-18, SELL EXECUTED, Price: 0.95, Cost: 9.50, Comm 0.00
# 2000-04-18, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2000-04-18, Close, 0.98
# 2000-04-19, Close, 0.93
# 2000-04-20, Close, 0.92
# 2000-04-20, BUY CREATE, 0.92
# 2000-04-24, BUY EXECUTED, Price: 0.89, Cost: 8.90, Comm 0.00
# 2000-04-24, Close, 0.93
# 2000-04-25, Close, 0.99
# 2000-04-25, SELL CREATE, 0.99
# 2000-04-26, SELL EXECUTED, Price: 0.98, Cost: 8.90, Comm 0.00
# 2000-04-26, OPERATION PROFIT, GROSS 0.90, NET 0.90
# 2000-04-26, Close, 0.93
# 2000-04-26, BUY CREATE, 0.93
# 2000-04-27, BUY EXECUTED, Price: 0.90, Cost: 9.00, Comm 0.00
# 2000-04-27, Close, 0.98
# 2000-04-27, SELL CREATE, 0.98
# 2000-04-28, SELL EXECUTED, Price: 0.98, Cost: 9.00, Comm 0.00
# 2000-04-28, OPERATION PROFIT, GROSS 0.80, NET 0.80
# 2000-04-28, Close, 0.96
# 2000-05-01, Close, 0.96
# 2000-05-01, BUY CREATE, 0.96
# 2000-05-02, BUY EXECUTED, Price: 0.95, Cost: 9.50, Comm 0.00
# 2000-05-02, Close, 0.91
# 2000-05-03, Close, 0.89
# 2000-05-04, Close, 0.85
# 2000-05-05, Close, 0.87
# 2000-05-08, Close, 0.85
# 2000-05-09, Close, 0.81
# 2000-05-10, Close, 0.76
# 2000-05-11, Close, 0.79
# 2000-05-12, Close, 0.83
# 2000-05-12, SELL CREATE, 0.83
# 2000-05-15, SELL EXECUTED, Price: 0.83, Cost: 9.50, Comm 0.00
# 2000-05-15, OPERATION PROFIT, GROSS -1.20, NET -1.20
# 2000-05-15, Close, 0.78
# 2000-05-15, BUY CREATE, 0.78
# 2000-05-16, BUY EXECUTED, Price: 0.81, Cost: 8.10, Comm 0.00
# 2000-05-16, Close, 0.81
# 2000-05-16, SELL CREATE, 0.81
# 2000-05-17, SELL EXECUTED, Price: 0.80, Cost: 8.10, Comm 0.00
# 2000-05-17, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2000-05-17, Close, 0.78
# 2000-05-17, BUY CREATE, 0.78
# 2000-05-18, BUY EXECUTED, Price: 0.79, Cost: 7.90, Comm 0.00
# 2000-05-18, Close, 0.78
# 2000-05-19, Close, 0.72
# 2000-05-22, Close, 0.69
# 2000-05-23, Close, 0.66
# 2000-05-24, Close, 0.68
# 2000-05-25, Close, 0.67
# 2000-05-26, Close, 0.67
# 2000-05-30, Close, 0.67
# 2000-05-31, Close, 0.65
# 2000-06-01, Close, 0.69
# 2000-06-01, SELL CREATE, 0.69
# 2000-06-02, SELL EXECUTED, Price: 0.72, Cost: 7.90, Comm 0.00
# 2000-06-02, OPERATION PROFIT, GROSS -0.70, NET -0.70
# 2000-06-02, Close, 0.71
# 2000-06-05, Close, 0.70
# 2000-06-06, Close, 0.72
# 2000-06-07, Close, 0.74
# 2000-06-08, Close, 0.73
# 2000-06-09, Close, 0.74
# 2000-06-12, Close, 0.70
# 2000-06-12, BUY CREATE, 0.70
# 2000-06-13, BUY EXECUTED, Price: 0.70, Cost: 7.00, Comm 0.00
# 2000-06-13, Close, 0.73
# 2000-06-13, SELL CREATE, 0.73
# 2000-06-14, SELL EXECUTED, Price: 0.73, Cost: 7.00, Comm 0.00
# 2000-06-14, OPERATION PROFIT, GROSS 0.30, NET 0.30
# 2000-06-14, Close, 0.70
# 2000-06-14, BUY CREATE, 0.70
# 2000-06-15, BUY EXECUTED, Price: 0.70, Cost: 7.00, Comm 0.00
# 2000-06-15, Close, 0.71
# 2000-06-16, Close, 0.70
# 2000-06-19, Close, 0.74
# 2000-06-19, SELL CREATE, 0.74
# 2000-06-20, SELL EXECUTED, Price: 0.76, Cost: 7.00, Comm 0.00
# 2000-06-20, OPERATION PROFIT, GROSS 0.60, NET 0.60
# 2000-06-20, Close, 0.78
# 2000-06-21, Close, 0.86
# 2000-06-22, Close, 0.83
# 2000-06-23, Close, 0.80
# 2000-06-23, BUY CREATE, 0.80
# 2000-06-26, BUY EXECUTED, Price: 0.81, Cost: 8.10, Comm 0.00
# 2000-06-26, Close, 0.83
# 2000-06-26, SELL CREATE, 0.83
# 2000-06-27, SELL EXECUTED, Price: 0.83, Cost: 8.10, Comm 0.00
# 2000-06-27, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-06-27, Close, 0.80
# 2000-06-27, BUY CREATE, 0.80
# 2000-06-28, BUY EXECUTED, Price: 0.82, Cost: 8.20, Comm 0.00
# 2000-06-28, Close, 0.84
# 2000-06-28, SELL CREATE, 0.84
# 2000-06-29, SELL EXECUTED, Price: 0.82, Cost: 8.20, Comm 0.00
# 2000-06-29, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2000-06-29, Close, 0.79
# 2000-06-29, BUY CREATE, 0.79
# 2000-06-30, BUY EXECUTED, Price: 0.81, Cost: 8.10, Comm 0.00
# 2000-06-30, Close, 0.81
# 2000-07-03, Close, 0.82
# 2000-07-03, SELL CREATE, 0.82
# 2000-07-05, SELL EXECUTED, Price: 0.82, Cost: 8.10, Comm 0.00
# 2000-07-05, OPERATION PROFIT, GROSS 0.10, NET 0.10
# 2000-07-05, Close, 0.80
# 2000-07-05, BUY CREATE, 0.80
# 2000-07-06, BUY EXECUTED, Price: 0.81, Cost: 8.10, Comm 0.00
# 2000-07-06, Close, 0.80
# 2000-07-07, Close, 0.84
# 2000-07-07, SELL CREATE, 0.84
# 2000-07-10, SELL EXECUTED, Price: 0.83, Cost: 8.10, Comm 0.00
# 2000-07-10, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-07-10, Close, 0.88
# 2000-07-11, Close, 0.88
# 2000-07-12, Close, 0.91
# 2000-07-13, Close, 0.87
# 2000-07-13, BUY CREATE, 0.87
# 2000-07-14, BUY EXECUTED, Price: 0.88, Cost: 8.80, Comm 0.00
# 2000-07-14, Close, 0.89
# 2000-07-14, SELL CREATE, 0.89
# 2000-07-17, SELL EXECUTED, Price: 0.90, Cost: 8.80, Comm 0.00
# 2000-07-17, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-07-17, Close, 0.90
# 2000-07-18, Close, 0.88
# 2000-07-18, BUY CREATE, 0.88
# 2000-07-19, BUY EXECUTED, Price: 0.85, Cost: 8.50, Comm 0.00
# 2000-07-19, Close, 0.81
# 2000-07-20, Close, 0.85
# 2000-07-21, Close, 0.83
# 2000-07-24, Close, 0.75
# 2000-07-25, Close, 0.77
# 2000-07-26, Close, 0.77
# 2000-07-27, Close, 0.80
# 2000-07-27, SELL CREATE, 0.80
# 2000-07-28, SELL EXECUTED, Price: 0.81, Cost: 8.50, Comm 0.00
# 2000-07-28, OPERATION PROFIT, GROSS -0.40, NET -0.40
# 2000-07-28, Close, 0.74
# 2000-07-28, BUY CREATE, 0.74
# 2000-07-31, BUY EXECUTED, Price: 0.76, Cost: 7.60, Comm 0.00
# 2000-07-31, Close, 0.78
# 2000-07-31, SELL CREATE, 0.78
# 2000-08-01, SELL EXECUTED, Price: 0.78, Cost: 7.60, Comm 0.00
# 2000-08-01, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-08-01, Close, 0.76
# 2000-08-01, BUY CREATE, 0.76
# 2000-08-02, BUY EXECUTED, Price: 0.75, Cost: 7.50, Comm 0.00
# 2000-08-02, Close, 0.73
# 2000-08-03, Close, 0.74
# 2000-08-04, Close, 0.73
# 2000-08-07, Close, 0.74
# 2000-08-08, Close, 0.72
# 2000-08-09, Close, 0.73
# 2000-08-10, Close, 0.73
# 2000-08-11, Close, 0.73
# 2000-08-14, Close, 0.72
# 2000-08-15, Close, 0.72
# 2000-08-16, Close, 0.75
# 2000-08-16, SELL CREATE, 0.75
# 2000-08-17, SELL EXECUTED, Price: 0.75, Cost: 7.50, Comm 0.00
# 2000-08-17, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2000-08-17, Close, 0.79
# 2000-08-18, Close, 0.77
# 2000-08-21, Close, 0.78
# 2000-08-22, Close, 0.80
# 2000-08-23, Close, 0.84
# 2000-08-24, Close, 0.86
# 2000-08-25, Close, 0.88
# 2000-08-28, Close, 0.89
# 2000-08-29, Close, 0.91
# 2000-08-30, Close, 0.92
# 2000-08-31, Close, 0.94
# 2000-09-01, Close, 0.98
# 2000-09-05, Close, 0.96
# 2000-09-06, Close, 0.90
# 2000-09-06, BUY CREATE, 0.90
# 2000-09-07, BUY EXECUTED, Price: 0.91, Cost: 9.10, Comm 0.00
# 2000-09-07, Close, 0.96
# 2000-09-07, SELL CREATE, 0.96
# 2000-09-08, SELL EXECUTED, Price: 0.95, Cost: 9.10, Comm 0.00
# 2000-09-08, OPERATION PROFIT, GROSS 0.40, NET 0.40
# 2000-09-08, Close, 0.91
# 2000-09-08, BUY CREATE, 0.91
# 2000-09-11, BUY EXECUTED, Price: 0.90, Cost: 9.00, Comm 0.00
# 2000-09-11, Close, 0.90
# 2000-09-12, Close, 0.89
# 2000-09-13, Close, 0.89
# 2000-09-14, Close, 0.88
# 2000-09-15, Close, 0.85
# 2000-09-18, Close, 0.93
# 2000-09-18, SELL CREATE, 0.93
# 2000-09-19, SELL EXECUTED, Price: 0.92, Cost: 9.00, Comm 0.00
# 2000-09-19, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-09-19, Close, 0.92
# 2000-09-20, Close, 0.94
# 2000-09-21, Close, 0.87
# 2000-09-21, BUY CREATE, 0.87
# 2000-09-22, BUY EXECUTED, Price: 0.78, Cost: 7.80, Comm 0.00
# 2000-09-22, Close, 0.80
# 2000-09-25, Close, 0.82
# 2000-09-26, Close, 0.79
# 2000-09-27, Close, 0.75
# 2000-09-28, Close, 0.82
# 2000-09-28, SELL CREATE, 0.82
# 2000-09-29, SELL EXECUTED, Price: 0.43, Cost: 7.80, Comm 0.00
# 2000-09-29, OPERATION PROFIT, GROSS -3.50, NET -3.50
# 2000-09-29, Close, 0.40
# 2000-09-29, BUY CREATE, 0.40
# 2000-10-02, BUY EXECUTED, Price: 0.41, Cost: 4.10, Comm 0.00
# 2000-10-02, Close, 0.37
# 2000-10-03, Close, 0.34
# 2000-10-04, Close, 0.36
# 2000-10-05, Close, 0.34
# 2000-10-06, Close, 0.34
# 2000-10-09, Close, 0.34
# 2000-10-10, Close, 0.32
# 2000-10-11, Close, 0.30
# 2000-10-12, Close, 0.31
# 2000-10-13, Close, 0.34
# 2000-10-13, SELL CREATE, 0.34
# 2000-10-16, SELL EXECUTED, Price: 0.34, Cost: 4.10, Comm 0.00
# 2000-10-16, OPERATION PROFIT, GROSS -0.70, NET -0.70
# 2000-10-16, Close, 0.33
# 2000-10-17, Close, 0.31
# 2000-10-17, BUY CREATE, 0.31
# 2000-10-18, BUY EXECUTED, Price: 0.30, Cost: 3.00, Comm 0.00
# 2000-10-18, Close, 0.31
# 2000-10-19, Close, 0.29
# 2000-10-20, Close, 0.30
# 2000-10-23, Close, 0.31
# 2000-10-23, SELL CREATE, 0.31
# 2000-10-24, SELL EXECUTED, Price: 0.32, Cost: 3.00, Comm 0.00
# 2000-10-24, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2000-10-24, Close, 0.29
# 2000-10-24, BUY CREATE, 0.29
# 2000-10-25, BUY EXECUTED, Price: 0.29, Cost: 2.90, Comm 0.00
# 2000-10-25, Close, 0.28
# 2000-10-26, Close, 0.28
# 2000-10-27, Close, 0.29
# 2000-10-30, Close, 0.30
# 2000-10-30, SELL CREATE, 0.30
# 2000-10-31, SELL EXECUTED, Price: 0.30, Cost: 2.90, Comm 0.00
# 2000-10-31, OPERATION PROFIT, GROSS 0.10, NET 0.10
# 2000-10-31, Close, 0.30
# 2000-11-01, Close, 0.32
# 2000-11-02, Close, 0.34
# 2000-11-03, Close, 0.34
# 2000-11-06, Close, 0.33
# 2000-11-07, Close, 0.33
# 2000-11-07, BUY CREATE, 0.33
# 2000-11-08, BUY EXECUTED, Price: 0.33, Cost: 3.30, Comm 0.00
# 2000-11-08, Close, 0.31
# 2000-11-09, Close, 0.31
# 2000-11-10, Close, 0.29
# 2000-11-13, Close, 0.30
# 2000-11-14, Close, 0.31
# 2000-11-14, SELL CREATE, 0.31
# 2000-11-15, SELL EXECUTED, Price: 0.31, Cost: 3.30, Comm 0.00
# 2000-11-15, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-11-15, Close, 0.31
# 2000-11-16, Close, 0.29
# 2000-11-16, BUY CREATE, 0.29
# 2000-11-17, BUY EXECUTED, Price: 0.30, Cost: 3.00, Comm 0.00
# 2000-11-17, Close, 0.28
# 2000-11-20, Close, 0.29
# 2000-11-21, Close, 0.29
# 2000-11-22, Close, 0.28
# 2000-11-24, Close, 0.30
# 2000-11-24, SELL CREATE, 0.30
# 2000-11-27, SELL EXECUTED, Price: 0.31, Cost: 3.00, Comm 0.00
# 2000-11-27, OPERATION PROFIT, GROSS 0.10, NET 0.10
# 2000-11-27, Close, 0.29
# 2000-11-28, Close, 0.28
# 2000-11-28, BUY CREATE, 0.28
# 2000-11-29, BUY EXECUTED, Price: 0.28, Cost: 2.80, Comm 0.00
# 2000-11-29, Close, 0.27
# 2000-11-30, Close, 0.25
# 2000-12-01, Close, 0.26
# 2000-12-04, Close, 0.26
# 2000-12-05, Close, 0.26
# 2000-12-06, Close, 0.22
# 2000-12-07, Close, 0.22
# 2000-12-08, Close, 0.23
# 2000-12-11, Close, 0.23
# 2000-12-12, Close, 0.24
# 2000-12-12, SELL CREATE, 0.24
# 2000-12-13, SELL EXECUTED, Price: 0.24, Cost: 2.80, Comm 0.00
# 2000-12-13, OPERATION PROFIT, GROSS -0.40, NET -0.40
# 2000-12-13, Close, 0.23
# 2000-12-14, Close, 0.22
# 2000-12-14, BUY CREATE, 0.22
# 2000-12-15, BUY EXECUTED, Price: 0.22, Cost: 2.20, Comm 0.00
# 2000-12-15, Close, 0.22
# 2000-12-18, Close, 0.22
# 2000-12-19, Close, 0.22
# 2000-12-20, Close, 0.22
# 2000-12-21, Close, 0.22
# 2000-12-22, Close, 0.23
# 2000-12-22, SELL CREATE, 0.23
# 2000-12-26, SELL EXECUTED, Price: 0.23, Cost: 2.20, Comm 0.00
# 2000-12-26, OPERATION PROFIT, GROSS 0.10, NET 0.10
# 2000-12-26, Close, 0.23
# 2000-12-27, Close, 0.23
# 2000-12-28, Close, 0.23
# 2000-12-29, Close, 0.23
# 2000-12-29, BUY CREATE, 0.23
# Final Portfolio Value: 998.50

# %%
tick  = YF(["MSFT", "AAPL"])
shares_outstanding = tick.get_key_statistics_data()

# %%
shares_outstanding["AAPL"]["sharesOutstanding"]
# Out:
# 16823300096

# %%
class MySizer(bt.Sizer):
    params = (
        ('stake', 1),
        ('size', 10)
    )

    def _getsizing(self, comminfo, cash, data, isbuy):
        if isbuy:
            return self.p.stake

        # Sell situation
        position = self.broker.getposition(data)
        if not position.size:
            return 0  # do not sell if nothing is open

        return self.p.stake

# %%
# Plotting with more indicators
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

        # Indicators for the plotting show
        bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
        bt.indicators.WeightedMovingAverage(self.datas[0], period=25,
                                            subplot=True)
        bt.indicators.StochasticSlow(self.datas[0])
        bt.indicators.MACDHisto(self.datas[0])
        rsi = bt.indicators.RSI(self.datas[0])
        bt.indicators.SmoothedMovingAverage(rsi, period=10)
        bt.indicators.ATR(self.datas[0], plot=False)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Create a Data Feed
    data = bt.feeds.YahooFinanceData(
        dataname="AAPL",
        # Do not pass values before this date
        fromdate=datetime.datetime(2000, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2000, 12, 31),
        reverse=False)
    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Plot the result
    cerebro.plot()
# Out:
# Starting Portfolio Value: 1000.00
# 2000-02-18, Close, 0.86
# 2000-02-18, BUY CREATE, 0.86
# 2000-02-22, BUY EXECUTED, Price: 0.85, Cost: 8.50, Comm 0.00
# 2000-02-22, Close, 0.88
# 2000-02-23, Close, 0.90
# 2000-02-24, Close, 0.89
# 2000-02-25, Close, 0.85
# 2000-02-25, SELL CREATE, 0.85
# 2000-02-28, SELL EXECUTED, Price: 0.85, Cost: 8.50, Comm 0.00
# 2000-02-28, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2000-02-28, Close, 0.87
# 2000-02-29, Close, 0.88
# 2000-02-29, BUY CREATE, 0.88
# 2000-03-01, BUY EXECUTED, Price: 0.91, Cost: 9.10, Comm 0.00
# 2000-03-01, Close, 1.00
# 2000-03-02, Close, 0.94
# 2000-03-03, Close, 0.99
# 2000-03-06, Close, 0.97
# 2000-03-07, Close, 0.95
# 2000-03-08, Close, 0.94
# 2000-03-09, Close, 0.94
# 2000-03-10, Close, 0.97
# 2000-03-13, Close, 0.93
# 2000-03-14, Close, 0.88
# 2000-03-14, SELL CREATE, 0.88
# 2000-03-15, SELL EXECUTED, Price: 0.89, Cost: 9.10, Comm 0.00
# 2000-03-15, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-03-15, Close, 0.90
# 2000-03-16, Close, 0.94
# 2000-03-16, BUY CREATE, 0.94
# 2000-03-17, BUY EXECUTED, Price: 0.93, Cost: 9.30, Comm 0.00
# 2000-03-17, Close, 0.96
# 2000-03-20, Close, 0.95
# 2000-03-21, Close, 1.04
# 2000-03-22, Close, 1.11
# 2000-03-23, Close, 1.09
# 2000-03-24, Close, 1.07
# 2000-03-27, Close, 1.07
# 2000-03-28, Close, 1.07
# 2000-03-29, Close, 1.05
# 2000-03-30, Close, 0.97
# 2000-03-30, SELL CREATE, 0.97
# 2000-03-31, SELL EXECUTED, Price: 0.98, Cost: 9.30, Comm 0.00
# 2000-03-31, OPERATION PROFIT, GROSS 0.50, NET 0.50
# 2000-03-31, Close, 1.05
# 2000-03-31, BUY CREATE, 1.05
# 2000-04-03, BUY EXECUTED, Price: 1.04, Cost: 10.40, Comm 0.00
# 2000-04-03, Close, 1.03
# 2000-04-04, Close, 0.98
# 2000-04-04, SELL CREATE, 0.98
# 2000-04-05, SELL EXECUTED, Price: 0.97, Cost: 10.40, Comm 0.00
# 2000-04-05, OPERATION PROFIT, GROSS -0.70, NET -0.70
# 2000-04-05, Close, 1.00
# 2000-04-06, Close, 0.96
# 2000-04-07, Close, 1.01
# 2000-04-10, Close, 0.96
# 2000-04-11, Close, 0.92
# 2000-04-12, Close, 0.84
# 2000-04-13, Close, 0.88
# 2000-04-14, Close, 0.86
# 2000-04-17, Close, 0.95
# 2000-04-18, Close, 0.98
# 2000-04-18, BUY CREATE, 0.98
# 2000-04-19, BUY EXECUTED, Price: 0.97, Cost: 9.70, Comm 0.00
# 2000-04-19, Close, 0.93
# 2000-04-19, SELL CREATE, 0.93
# 2000-04-20, SELL EXECUTED, Price: 0.95, Cost: 9.70, Comm 0.00
# 2000-04-20, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-04-20, Close, 0.92
# 2000-04-24, Close, 0.93
# 2000-04-25, Close, 0.99
# 2000-04-25, BUY CREATE, 0.99
# 2000-04-26, BUY EXECUTED, Price: 0.98, Cost: 9.80, Comm 0.00
# 2000-04-26, Close, 0.93
# 2000-04-26, SELL CREATE, 0.93
# 2000-04-27, SELL EXECUTED, Price: 0.90, Cost: 9.80, Comm 0.00
# 2000-04-27, OPERATION PROFIT, GROSS -0.80, NET -0.80
# 2000-04-27, Close, 0.98
# 2000-04-27, BUY CREATE, 0.98
# 2000-04-28, BUY EXECUTED, Price: 0.98, Cost: 9.80, Comm 0.00
# 2000-04-28, Close, 0.96
# 2000-05-01, Close, 0.96
# 2000-05-02, Close, 0.91
# 2000-05-02, SELL CREATE, 0.91
# 2000-05-03, SELL EXECUTED, Price: 0.92, Cost: 9.80, Comm 0.00
# 2000-05-03, OPERATION PROFIT, GROSS -0.60, NET -0.60
# 2000-05-03, Close, 0.89
# 2000-05-04, Close, 0.85
# 2000-05-05, Close, 0.87
# 2000-05-08, Close, 0.85
# 2000-05-09, Close, 0.81
# 2000-05-10, Close, 0.76
# 2000-05-11, Close, 0.79
# 2000-05-12, Close, 0.83
# 2000-05-15, Close, 0.78
# 2000-05-16, Close, 0.81
# 2000-05-17, Close, 0.78
# 2000-05-18, Close, 0.78
# 2000-05-19, Close, 0.72
# 2000-05-22, Close, 0.69
# 2000-05-23, Close, 0.66
# 2000-05-24, Close, 0.68
# 2000-05-25, Close, 0.67
# 2000-05-26, Close, 0.67
# 2000-05-30, Close, 0.67
# 2000-05-31, Close, 0.65
# 2000-06-01, Close, 0.69
# 2000-06-02, Close, 0.71
# 2000-06-05, Close, 0.70
# 2000-06-06, Close, 0.72
# 2000-06-06, BUY CREATE, 0.72
# 2000-06-07, BUY EXECUTED, Price: 0.72, Cost: 7.20, Comm 0.00
# 2000-06-07, Close, 0.74
# 2000-06-08, Close, 0.73
# 2000-06-09, Close, 0.74
# 2000-06-12, Close, 0.70
# 2000-06-13, Close, 0.73
# 2000-06-14, Close, 0.70
# 2000-06-15, Close, 0.71
# 2000-06-16, Close, 0.70
# 2000-06-16, SELL CREATE, 0.70
# 2000-06-19, SELL EXECUTED, Price: 0.70, Cost: 7.20, Comm 0.00
# 2000-06-19, OPERATION PROFIT, GROSS -0.20, NET -0.20
# 2000-06-19, Close, 0.74
# 2000-06-19, BUY CREATE, 0.74
# 2000-06-20, BUY EXECUTED, Price: 0.76, Cost: 7.60, Comm 0.00
# 2000-06-20, Close, 0.78
# 2000-06-21, Close, 0.86
# 2000-06-22, Close, 0.83
# 2000-06-23, Close, 0.80
# 2000-06-26, Close, 0.83
# 2000-06-27, Close, 0.80
# 2000-06-28, Close, 0.84
# 2000-06-29, Close, 0.79
# 2000-06-30, Close, 0.81
# 2000-07-03, Close, 0.82
# 2000-07-05, Close, 0.80
# 2000-07-06, Close, 0.80
# 2000-07-07, Close, 0.84
# 2000-07-10, Close, 0.88
# 2000-07-11, Close, 0.88
# 2000-07-12, Close, 0.91
# 2000-07-13, Close, 0.87
# 2000-07-14, Close, 0.89
# 2000-07-17, Close, 0.90
# 2000-07-18, Close, 0.88
# 2000-07-19, Close, 0.81
# 2000-07-19, SELL CREATE, 0.81
# 2000-07-20, SELL EXECUTED, Price: 0.85, Cost: 7.60, Comm 0.00
# 2000-07-20, OPERATION PROFIT, GROSS 0.90, NET 0.90
# 2000-07-20, Close, 0.85
# 2000-07-20, BUY CREATE, 0.85
# 2000-07-21, BUY EXECUTED, Price: 0.84, Cost: 8.40, Comm 0.00
# 2000-07-21, Close, 0.83
# 2000-07-21, SELL CREATE, 0.83
# 2000-07-24, SELL EXECUTED, Price: 0.81, Cost: 8.40, Comm 0.00
# 2000-07-24, OPERATION PROFIT, GROSS -0.30, NET -0.30
# 2000-07-24, Close, 0.75
# 2000-07-25, Close, 0.77
# 2000-07-26, Close, 0.77
# 2000-07-27, Close, 0.80
# 2000-07-28, Close, 0.74
# 2000-07-31, Close, 0.78
# 2000-08-01, Close, 0.76
# 2000-08-02, Close, 0.73
# 2000-08-03, Close, 0.74
# 2000-08-04, Close, 0.73
# 2000-08-07, Close, 0.74
# 2000-08-08, Close, 0.72
# 2000-08-09, Close, 0.73
# 2000-08-10, Close, 0.73
# 2000-08-11, Close, 0.73
# 2000-08-14, Close, 0.72
# 2000-08-15, Close, 0.72
# 2000-08-16, Close, 0.75
# 2000-08-16, BUY CREATE, 0.75
# 2000-08-17, BUY EXECUTED, Price: 0.75, Cost: 7.50, Comm 0.00
# 2000-08-17, Close, 0.79
# 2000-08-18, Close, 0.77
# 2000-08-21, Close, 0.78
# 2000-08-22, Close, 0.80
# 2000-08-23, Close, 0.84
# 2000-08-24, Close, 0.86
# 2000-08-25, Close, 0.88
# 2000-08-28, Close, 0.89
# 2000-08-29, Close, 0.91
# 2000-08-30, Close, 0.92
# 2000-08-31, Close, 0.94
# 2000-09-01, Close, 0.98
# 2000-09-05, Close, 0.96
# 2000-09-06, Close, 0.90
# 2000-09-07, Close, 0.96
# 2000-09-08, Close, 0.91
# 2000-09-11, Close, 0.90
# 2000-09-12, Close, 0.89
# 2000-09-12, SELL CREATE, 0.89
# 2000-09-13, SELL EXECUTED, Price: 0.87, Cost: 7.50, Comm 0.00
# 2000-09-13, OPERATION PROFIT, GROSS 1.20, NET 1.20
# 2000-09-13, Close, 0.89
# 2000-09-14, Close, 0.88
# 2000-09-15, Close, 0.85
# 2000-09-18, Close, 0.93
# 2000-09-18, BUY CREATE, 0.93
# 2000-09-19, BUY EXECUTED, Price: 0.92, Cost: 9.20, Comm 0.00
# 2000-09-19, Close, 0.92
# 2000-09-20, Close, 0.94
# 2000-09-21, Close, 0.87
# 2000-09-21, SELL CREATE, 0.87
# 2000-09-22, SELL EXECUTED, Price: 0.78, Cost: 9.20, Comm 0.00
# 2000-09-22, OPERATION PROFIT, GROSS -1.40, NET -1.40
# 2000-09-22, Close, 0.80
# 2000-09-25, Close, 0.82
# 2000-09-26, Close, 0.79
# 2000-09-27, Close, 0.75
# 2000-09-28, Close, 0.82
# 2000-09-29, Close, 0.40
# 2000-10-02, Close, 0.37
# 2000-10-03, Close, 0.34
# 2000-10-04, Close, 0.36
# 2000-10-05, Close, 0.34
# 2000-10-06, Close, 0.34
# 2000-10-09, Close, 0.34
# 2000-10-10, Close, 0.32
# 2000-10-11, Close, 0.30
# 2000-10-12, Close, 0.31
# 2000-10-13, Close, 0.34
# 2000-10-16, Close, 0.33
# 2000-10-17, Close, 0.31
# 2000-10-18, Close, 0.31
# 2000-10-19, Close, 0.29
# 2000-10-20, Close, 0.30
# 2000-10-23, Close, 0.31
# 2000-10-24, Close, 0.29
# 2000-10-25, Close, 0.28
# 2000-10-26, Close, 0.28
# 2000-10-27, Close, 0.29
# 2000-10-30, Close, 0.30
# 2000-10-31, Close, 0.30
# 2000-11-01, Close, 0.32
# 2000-11-01, BUY CREATE, 0.32
# 2000-11-02, BUY EXECUTED, Price: 0.33, Cost: 3.30, Comm 0.00
# 2000-11-02, Close, 0.34
# 2000-11-03, Close, 0.34
# 2000-11-06, Close, 0.33
# 2000-11-07, Close, 0.33
# 2000-11-08, Close, 0.31
# 2000-11-09, Close, 0.31
# 2000-11-10, Close, 0.29
# 2000-11-10, SELL CREATE, 0.29
# 2000-11-13, SELL EXECUTED, Price: 0.29, Cost: 3.30, Comm 0.00
# 2000-11-13, OPERATION PROFIT, GROSS -0.40, NET -0.40
# 2000-11-13, Close, 0.30
# 2000-11-14, Close, 0.31
# 2000-11-14, BUY CREATE, 0.31
# 2000-11-15, BUY EXECUTED, Price: 0.31, Cost: 3.10, Comm 0.00
# 2000-11-15, Close, 0.31
# 2000-11-15, SELL CREATE, 0.31
# 2000-11-16, SELL EXECUTED, Price: 0.30, Cost: 3.10, Comm 0.00
# 2000-11-16, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2000-11-16, Close, 0.29
# 2000-11-17, Close, 0.28
# 2000-11-20, Close, 0.29
# 2000-11-21, Close, 0.29
# 2000-11-22, Close, 0.28
# 2000-11-24, Close, 0.30
# 2000-11-27, Close, 0.29
# 2000-11-28, Close, 0.28
# 2000-11-29, Close, 0.27
# 2000-11-30, Close, 0.25
# 2000-12-01, Close, 0.26
# 2000-12-04, Close, 0.26
# 2000-12-05, Close, 0.26
# 2000-12-06, Close, 0.22
# 2000-12-07, Close, 0.22
# 2000-12-08, Close, 0.23
# 2000-12-11, Close, 0.23
# 2000-12-12, Close, 0.24
# 2000-12-13, Close, 0.23
# 2000-12-14, Close, 0.22
# 2000-12-15, Close, 0.22
# 2000-12-18, Close, 0.22
# 2000-12-19, Close, 0.22
# 2000-12-20, Close, 0.22
# 2000-12-21, Close, 0.22
# 2000-12-22, Close, 0.23
# 2000-12-22, BUY CREATE, 0.23
# 2000-12-26, BUY EXECUTED, Price: 0.23, Cost: 2.30, Comm 0.00
# 2000-12-26, Close, 0.23
# 2000-12-27, Close, 0.23
# 2000-12-28, Close, 0.23
# 2000-12-29, Close, 0.23
# Final Portfolio Value: 997.70
# <img src="data:image/png;base64,..." width="640">

# %%
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
        ('printlog', False),
    )

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function fot this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] > self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

    def stop(self):
        self.log('(MA Period %2d) Ending Value %.2f' %
                 (self.params.maperiod, self.broker.getvalue()), doprint=True)


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.optstrategy(
        TestStrategy,
        maperiod=range(10, 31))

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceData(
        dataname="AAPL",
        # Do not pass values before this date
        fromdate=datetime.datetime(2019, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 12, 31),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Run over everything
    cerebro.run(maxcpus=1)
# Out:
# 2020-12-30, (MA Period 10) Ending Value 1421.60
# 2020-12-30, (MA Period 11) Ending Value 1333.40
# 2020-12-30, (MA Period 12) Ending Value 1330.60
# 2020-12-30, (MA Period 13) Ending Value 1314.50
# 2020-12-30, (MA Period 14) Ending Value 1301.70
# 2020-12-30, (MA Period 15) Ending Value 1322.00
# 2020-12-30, (MA Period 16) Ending Value 1256.50
# 2020-12-30, (MA Period 17) Ending Value 1263.10
# 2020-12-30, (MA Period 18) Ending Value 1263.40
# 2020-12-30, (MA Period 19) Ending Value 1272.20
# 2020-12-30, (MA Period 20) Ending Value 1065.90
# 2020-12-30, (MA Period 21) Ending Value 1060.90
# 2020-12-30, (MA Period 22) Ending Value 1311.10
# 2020-12-30, (MA Period 23) Ending Value 1061.20
# 2020-12-30, (MA Period 24) Ending Value 1028.30
# 2020-12-30, (MA Period 25) Ending Value 1033.80
# 2020-12-30, (MA Period 26) Ending Value 1013.40
# 2020-12-30, (MA Period 27) Ending Value 1021.50
# 2020-12-30, (MA Period 28) Ending Value 994.40
# 2020-12-30, (MA Period 29) Ending Value 997.50
# 2020-12-30, (MA Period 30) Ending Value 975.00
